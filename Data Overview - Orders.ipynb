# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Import CSV Data - Oddle_Assignment Orders Data.csv

# %%
# Create pandas DF
orders_df = pd.read_csv("Oddle_Assignment Orders Data.csv")

# %%
# Check imported dataframe
orders_df.head()
# Out:
#    Unnamed: 0         submitted_on  pickup        delivery_date  \
# 0           1  2016-12-19 03:55:08       0  2016-12-21 12:00:00
# 1           2  2016-12-17 12:25:17       0  2016-12-17 14:00:00
# 2           3  2016-12-19 15:31:31       1  2016-12-24 04:00:00
# 3           4  2016-12-18 17:38:36       1  2016-12-26 04:30:00
# 4           5  2016-12-18 03:37:55       0  2016-12-23 09:15:00
#
#   customer_address_postal promotion_code  lead_time  basket_size  \
# 0                  823663            NaN     2160.0        64.45
# 1                  391010            NaN       60.0        74.99
# 2                     NaN            NaN     2880.0        77.66
# 3                  575312            NaN     4320.0        57.27
# 4                  188770          1212,      120.0       138.95
#
#    customer_index  menu_id   merchant_type  organisation_name_provided
# 0           27874        1           Cakes                         0.0
# 1            7983        2  Korean Chicken                         0.0
# 2           21225        3           Cakes                         0.0
# 3           42870        4           Cakes                         0.0
# 4           11021        5         Dim Sum                         0.0

# %%
## Reset the Indexes
orders_df = orders_df.drop('Unnamed: 0', axis=1)

# %%
orders_df.head()
# Out:
#           submitted_on  pickup        delivery_date customer_address_postal  \
# 0  2016-12-19 03:55:08       0  2016-12-21 12:00:00                  823663
# 1  2016-12-17 12:25:17       0  2016-12-17 14:00:00                  391010
# 2  2016-12-19 15:31:31       1  2016-12-24 04:00:00                     NaN
# 3  2016-12-18 17:38:36       1  2016-12-26 04:30:00                  575312
# 4  2016-12-18 03:37:55       0  2016-12-23 09:15:00                  188770
#
#   promotion_code  lead_time  basket_size  customer_index  menu_id  \
# 0            NaN     2160.0        64.45           27874        1
# 1            NaN       60.0        74.99            7983        2
# 2            NaN     2880.0        77.66           21225        3
# 3            NaN     4320.0        57.27           42870        4
# 4          1212,      120.0       138.95           11021        5
#
#     merchant_type  organisation_name_provided
# 0           Cakes                         0.0
# 1  Korean Chicken                         0.0
# 2           Cakes                         0.0
# 3           Cakes                         0.0
# 4         Dim Sum                         0.0

# %% [markdown]
# # Dataset Overview

# %% [markdown]
# ## Check Dimensions of the Dataset.

# %%
# Check Dimensions
orders_df.shape

# 22121 observations (rows)
# 11 Features (cols)
# Out:
# (22121, 11)

# %% [markdown]
# ## Check for Missing Values

# %%
# Check for Missing Values
orders_df.isnull().sum()

## customer_address_postal has 3371 nulls
## promotion_code has 19237 nulls
## organisation_Name_provided has 7 nulls
# Out:
# submitted_on                      0
# pickup                            0
# delivery_date                     0
# customer_address_postal        3371
# promotion_code                19237
# lead_time                         1
# basket_size                       0
# customer_index                    0
# menu_id                           0
# merchant_type                     0
# organisation_name_provided        7
# dtype: int64

# %% [markdown]
# ## Check for Datatypes (changed accordingly for work to be done in python)

# %%
#Check data types
orders_df.dtypes

## From the data dictionary provided in the Assignment PDF
# submitted_on == Date Time for order submission
# pickup == 1/0 binary
# delivery_date == Date Time
# customer_address_postal   == String -> need to convert to 6 digit integer
# promotion_code == String obj
# lead_time == integer (No. of mins) -> Might convert to time object
# basket_size  == float ($$ worth of basket)
# customer_index == customer ID, unique integer (Match from customer table)
# menu_id == Merchant ID
# merchant_type == String obj categorical
# organisation_name_provided == binary 1/0 (Corporate or not)
# Out:
# submitted_on                   object
# pickup                          int64
# delivery_date                  object
# customer_address_postal        object
# promotion_code                 object
# lead_time                     float64
# basket_size                   float64
# customer_index                  int64
# menu_id                         int64
# merchant_type                  object
# organisation_name_provided    float64
# dtype: object

# %% [markdown]
# ## Check for Duplicates, Validity etc

# %% [markdown]
# ### submitted_on

# %%
# Check duplicates for 'submitted_on'
orders_df['submitted_on'].duplicated().sum()

# 6 duplicates of the created date and time

### However this is to be ignored. Nothing wrong with users ordering simultaneously.
# Out:
# 6

# %%
# Adjust datatypes for the dataframe:
## submitted_on = datetime.
orders_df['submitted_on'] = pd.to_datetime(orders_df['submitted_on'])

# %%
orders_df['submitted_on'].max()
# Out:
# Timestamp('2018-09-30 22:56:17')

# %%
orders_df['submitted_on'].min()
# Out:
# Timestamp('2016-10-01 03:56:03')

# %% [markdown]
# ### pickup

# %%
## Check PickUp
orders_df['pickup'].value_counts()

# No funny values - Just binary 1/0
# Out:
# 0    16167
# 1     5954
# Name: pickup, dtype: int64

# %% [markdown]
# ### delivery_date (Date time)

# %%
# Check duplicates for 'delivery_date'
orders_df['delivery_date'].duplicated().sum()

# 11643 duplicates of the created date and time

### However this is to be ignored. Nothing wrong with users ordering simultaneously.
# Out:
# 11643

# %%
# Adjust datatypes for the dataframe:
## delivery_date = datetime.
orders_df['delivery_date'] = pd.to_datetime(orders_df['delivery_date'])

# %%
orders_df['delivery_date'].max()
# Out:
# Timestamp('2018-12-30 06:00:00')

# %%
orders_df['delivery_date'].min()
# Out:
# Timestamp('2016-10-01 07:00:00')

# %% [markdown]
# ### customer_address_postal

# %%
# Check validity/errors for 'customer_address_postal'
# Not concerned about duplicates because can be delivered to the same place

orders_df['customer_address_postal'].isnull().sum()
# Out:
# 3371

# %%
## Postalcode checker function - Check that the postal code entered by the user is in a valid 6 digits
## returns a boolean to a result column
## We will approach the clean up or the replacement etc after we do the validity check.
## Potential errors that we are looking for are things like S123456 (Because we are used to putting a prefix 'S')
## Additional chars other than the 6 digits
## Will do format conversion after we check the validity

def is_valid_postal(code):
    ## Current format is still a string
    if type(code) == str:
        if len(code) == 6:
            return True
        else:
            return False
    else:
        return False

# %%
## Testing.. Ok
is_valid_postal(123123)
# Out:
# False

# %%
## Apply the function
orders_df['postal_valid'] = orders_df['customer_address_postal'].apply(lambda x: is_valid_postal(x))

# %%
## Check the counts
orders_df['postal_valid'].value_counts()
# Out:
# True     18449
# False     3672
# Name: postal_valid, dtype: int64

# %%
orders_df.loc[(orders_df['postal_valid'] == False) &  (orders_df['customer_address_postal'].notnull())]

## We see 'Singapore, Blocks, S, we still see 6 digits. But there may be a SPACE or something in there.
# Out:
#              submitted_on  pickup       delivery_date  \
# 26    2016-12-19 12:36:34       0 2016-12-23 02:45:00
# 50    2016-12-28 03:15:37       0 2016-12-30 07:00:00
# 121   2016-12-20 15:57:36       1 2016-12-24 04:00:00
# 133   2016-12-21 04:29:31       1 2016-12-24 04:00:00
# 178   2016-12-22 22:26:02       0 2016-12-28 09:30:00
# 345   2016-12-30 01:44:04       0 2016-12-30 07:00:00
# 446   2017-01-03 12:12:15       0 2017-01-04 07:00:00
# 575   2017-12-04 04:31:51       0 2017-12-16 02:30:00
# 593   2017-12-04 09:55:52       0 2017-12-05 05:30:00
# 664   2017-12-05 15:12:20       0 2017-12-17 03:30:00
# 703   2017-12-06 08:35:23       0 2017-12-15 09:30:00
# 715   2018-02-02 02:29:37       0 2018-02-05 02:00:00
# 739   2018-02-03 01:51:44       0 2018-02-03 11:00:00
# 848   2018-02-06 01:29:27       0 2018-02-08 07:00:00
# 905   2017-12-29 01:13:01       0 2018-01-03 04:30:00
# 994   2018-01-06 14:41:02       1 2018-01-11 06:00:00
# 1102  2016-10-04 03:05:25       0 2016-10-04 05:00:00
# 1216  2018-03-09 02:43:08       0 2018-03-19 03:30:00
# 1247  2018-03-11 05:41:47       0 2018-03-17 09:00:00
# 1275  2018-03-12 07:29:40       0 2018-03-17 09:00:00
# 1293  2017-04-10 13:21:41       0 2017-04-12 07:00:00
# 1294  2017-04-10 13:14:51       0 2017-04-12 07:00:00
# 1510  2018-03-07 03:52:24       1 2018-03-12 07:00:00
# 1522  2018-03-07 08:02:27       0 2018-03-10 02:30:00
# 1776  2018-02-26 12:41:34       0 2018-03-01 12:00:00
# 1838  2018-02-26 08:03:34       0 2018-02-27 02:00:00
# 1900  2017-09-18 10:19:30       0 2017-09-19 04:00:00
# 1904  2017-09-18 11:23:11       0 2017-09-19 03:30:00
# 2003  2017-09-22 07:27:12       0 2017-09-29 02:30:00
# 2118  2017-10-08 11:08:20       0 2017-10-12 04:00:00
# ...                   ...     ...                 ...
# 19302 2017-12-14 10:39:49       0 2017-12-14 12:00:00
# 19365 2016-10-10 04:27:57       0 2016-10-14 04:00:00
# 19368 2016-10-10 11:57:06       0 2016-10-14 04:00:00
# 19443 2016-10-12 09:36:34       0 2016-10-13 12:00:00
# 19466 2016-10-13 04:28:10       0 2016-10-14 07:15:00
# 19527 2016-11-09 08:22:02       1 2016-11-15 07:00:00
# 19578 2018-03-08 04:06:44       1 2018-03-11 03:00:00
# 19583 2018-03-08 04:51:27       0 2018-03-09 03:30:00
# 19635 2018-08-11 02:28:30       0 2018-08-13 04:00:00
# 19787 2018-08-15 11:53:26       1 2018-08-16 03:00:00
# 19788 2018-08-15 06:18:40       0 2018-08-16 03:00:00
# 20150 2018-07-04 09:28:09       0 2018-07-09 03:30:00
# 20171 2018-07-05 08:54:22       0 2018-07-06 03:30:00
# 20217 2017-10-19 08:20:23       0 2017-10-21 05:30:00
# 20220 2017-10-18 07:16:10       0 2017-10-21 02:30:00
# 20225 2017-10-18 09:22:05       0 2017-10-28 08:30:00
# 20298 2017-11-28 12:13:13       0 2017-11-29 07:00:00
# 20309 2017-12-15 09:55:35       0 2017-12-15 12:30:00
# 20393 2017-12-18 08:45:02       0 2017-12-19 04:00:00
# 20552 2017-12-26 06:57:55       0 2017-12-26 10:00:00
# 20636 2016-11-21 17:32:11       0 2016-11-26 02:30:00
# 20663 2016-12-08 07:53:46       1 2016-12-24 03:00:00
# 20867 2017-02-07 02:13:55       0 2017-02-10 02:30:00
# 21096 2018-08-23 07:11:21       0 2018-08-29 03:30:00
# 21107 2018-08-30 05:36:06       0 2018-08-31 04:00:00
# 21124 2018-08-24 06:17:52       1 2018-09-01 09:00:00
# 21201 2018-08-27 02:32:06       0 2018-08-28 03:00:00
# 21381 2018-08-30 04:36:01       0 2018-09-02 10:30:00
# 21419 2018-09-28 03:30:17       0 2018-10-02 03:00:00
# 21559 2018-09-04 04:04:04       0 2018-09-05 03:00:00
#
#                                  customer_address_postal promotion_code  \
# 26                                      Singapore 319400            NaN
# 50                                            Block 264             NaN
# 121                                              S570442            NaN
# 133                                     Singapore 570308            NaN
# 178                                                 1543            NaN
# 345                                          71 Ayer Raj            NaN
# 446                                              567720             NaN
# 575                                              530911             NaN
# 593                                     SINGAPORE 187969            NaN
# 664                        Marina Bay Residences, 018980            NaN
# 703                                              S257889            NaN
# 715                                               238843            NaN
# 739                                     Singapore 079908            NaN
# 848                                              ​069543            NaN
# 905                                              120453             NaN
# 994                                              s828748        FIRST5,
# 1102                                             S159052            NaN
# 1216                                              636986            NaN
# 1247                  Marine Cove ( Outside Coffee Bean)        FIRST5,
# 1275                         Aloha Loyang Resort S507020        FIRST5,
# 1293                                             S518088            NaN
# 1294                                             138675             NaN
# 1510                                        Self collect            NaN
# 1522                                     09-07 Heliconia            NaN
# 1776                                             640739          10OFF,
# 1838             Standard Chartered Bank 68 Orchard Road            NaN
# 1900                                 21 Lorong Liew Lian            NaN
# 1904                                             339509             NaN
# 2003                                               18961            NaN
# 2118                                          Block 845             NaN
# ...                                                  ...            ...
# 19302                                            739000             NaN
# 19365                               23 Palm Grove Avenue            NaN
# 19368                                     1 Raffles Link            NaN
# 19443                                            018989             NaN
# 19466                            71 Robinson Road #04-02            NaN
# 19527                                 72 Hua Guan Avenue            NaN
# 19578                                   Pasir ris st 51             NaN
# 19583                        1 HarbourFront Place #12-04            NaN
# 19635                                  22 Sin Ming Lane             NaN
# 19787                         11 north buona vista drive            NaN
# 19788                         11 north buona vista drive            NaN
# 20150                          9 North Buona Vista Drive            NaN
# 20171                                   21 Biopolis Road            NaN
# 20217                                            823226        FIRST10,
# 20220                                  08-46 Changi Rise            NaN
# 20225                                             299323            NaN
# 20298                                             189556         10OFF,
# 20309  1 lower kent ridge road, NUH main building war...        XMAS20,
# 20393                                                51             NaN
# 20552                            Block 812C, Unit 11-623            NaN
# 20636                                            229616             NaN
# 20663                                          Blk 144              NaN
# 20867                             1 bedok south avenue 2            NaN
# 21096                          9 North Buona Vista Drive            NaN
# 21107                                            `409020            NaN
# 21124                          81A Serangoon Garden Way             NaN
# 21201                                            s138567            NaN
# 21381                                                 45            NaN
# 21419                                            s138567            NaN
# 21559  RHB Bank 440/442 Upper Bukit Timah Road , The ...            NaN
#
#        lead_time  basket_size  customer_index  menu_id   merchant_type  \
# 26         120.0       173.08           11045        5         Dim Sum
# 50        2160.0        85.89           28027        1           Cakes
# 121       2880.0        51.95           21236        3           Cakes
# 133       2160.0       162.93           27939        1           Cakes
# 178       2880.0        46.39           21248        3           Cakes
# 345         60.0        63.28             630        2  Korean Chicken
# 446        150.0        88.87           19605        5         Dim Sum
# 575       2880.0        82.45           21353        3           Cakes
# 593        150.0       181.44           11255        5         Dim Sum
# 664        150.0       251.76           13444        5         Dim Sum
# 703       2880.0       102.91           21388        3           Cakes
# 715        150.0       156.44           19401        5         Dim Sum
# 739         90.0       100.59             795        2  Korean Chicken
# 848        720.0        83.75           33733        1           Cakes
# 905       2880.0       214.64           21280        3           Cakes
# 994       4320.0        53.89           43123        4           Cakes
# 1102        60.0        56.97            5768        2  Korean Chicken
# 1216        20.0       102.97           42592        6           Salad
# 1247      4320.0        82.06           43181        4           Cakes
# 1275      4320.0        99.12           43192        4           Cakes
# 1293       720.0       115.66           34632        1           Cakes
# 1294       720.0        87.06           32909        1           Cakes
# 1510      2880.0        74.07           21607        3           Cakes
# 1522      2880.0       102.05           21611        3           Cakes
# 1776       720.0       119.75           28730        1           Cakes
# 1838       150.0       155.57           12045        5         Dim Sum
# 1900       720.0        61.20           28784        1           Cakes
# 1904        20.0       346.56           40653        6           Salad
# 2003      2880.0       185.15           21739        3           Cakes
# 2118      4320.0        92.47           48575        4           Cakes
# ...          ...          ...             ...      ...             ...
# 19302       60.0        59.33            4587        2  Korean Chicken
# 19365     4320.0        69.03           49303        4           Cakes
# 19368      720.0       108.24           38446        1           Cakes
# 19443      720.0       126.35           38478        1           Cakes
# 19466      120.0       262.74           19614        5         Dim Sum
# 19527     2880.0        52.83           22335        3           Cakes
# 19578      720.0        28.48           28602        1           Cakes
# 19583       20.0       109.34           42594        6           Salad
# 19635      150.0       163.77           18290        5         Dim Sum
# 19787       15.0        33.82           42425        6           Salad
# 19788       20.0       126.42           42425        6           Salad
# 20150       20.0       271.83           42674        6           Salad
# 20171       20.0       141.96           42672        6           Salad
# 20217      150.0       125.63           19806        5         Dim Sum
# 20220     2880.0       311.44           25833        3           Cakes
# 20225     2880.0        91.87           27294        3           Cakes
# 20298      720.0       154.45           32669        1           Cakes
# 20309       30.0        90.81           41943        6           Salad
# 20393       60.0        94.11             759        2  Korean Chicken
# 20552       60.0        74.06            1578        2  Korean Chicken
# 20636     2880.0        84.41           27390        3           Cakes
# 20663     2880.0        71.45           22545        3           Cakes
# 20867     2880.0        71.72           24136        3           Cakes
# 21096       20.0       311.10           42674        6           Salad
# 21107      150.0       217.08           20852        5         Dim Sum
# 21124     2880.0       101.26           26087        3           Cakes
# 21201       20.0        83.02           40845        6           Salad
# 21381      150.0       134.03           20499        5         Dim Sum
# 21419       20.0       106.92           40845        6           Salad
# 21559      150.0       111.12           16918        5         Dim Sum
#
#        organisation_name_provided  postal_valid
# 26                            0.0         False
# 50                            0.0         False
# 121                           0.0         False
# 133                           0.0         False
# 178                           0.0         False
# 345                           0.0         False
# 446                           0.0         False
# 575                           0.0         False
# 593                           1.0         False
# 664                           0.0         False
# 703                           0.0         False
# 715                           0.0         False
# 739                           0.0         False
# 848                           0.0         False
# 905                           0.0         False
# 994                           0.0         False
# 1102                          0.0         False
# 1216                          1.0         False
# 1247                          0.0         False
# 1275                          0.0         False
# 1293                          0.0         False
# 1294                          0.0         False
# 1510                          1.0         False
# 1522                          0.0         False
# 1776                          0.0         False
# 1838                          1.0         False
# 1900                          0.0         False
# 1904                          0.0         False
# 2003                          0.0         False
# 2118                          1.0         False
# ...                           ...           ...
# 19302                         0.0         False
# 19365                         0.0         False
# 19368                         0.0         False
# 19443                         0.0         False
# 19466                         0.0         False
# 19527                         0.0         False
# 19578                         0.0         False
# 19583                         1.0         False
# 19635                         1.0         False
# 19787                         1.0         False
# 19788                         1.0         False
# 20150                         1.0         False
# 20171                         1.0         False
# 20217                         0.0         False
# 20220                         0.0         False
# 20225                         0.0         False
# 20298                         0.0         False
# 20309                         0.0         False
# 20393                         1.0         False
# 20552                         0.0         False
# 20636                         0.0         False
# 20663                         0.0         False
# 20867                         0.0         False
# 21096                         1.0         False
# 21107                         1.0         False
# 21124                         0.0         False
# 21201                         0.0         False
# 21381                         0.0         False
# 21419                         0.0         False
# 21559                         1.0         False
#
# [301 rows x 12 columns]

# %%
## Create Cleaned up / Corrected postal codes
## We only want to extract 6 digits intact -> replace the problem ones with NULL

def clean_postals(code):
    code = str(code)
    x = re.findall(r"\D(\d{6})\D", " "+code+" ")
    if len(x) == 0:
        #print('Not Valid')
        return np.nan
    else:
       #print(x[0])
        return x[0]

# %%
orders_df['postal_good'] = orders_df['customer_address_postal'].apply(lambda x: clean_postals(x))

# %% [markdown]
# s= "123108"
# x = re.findall(r"\D(\d{6})\D", " "+s+" ")
#
# if len(x) == 0:
#     print('Not Valid')
#     return np.nan
# else:
#     print(x[0])
#     return x[0]

# %%
orders_df['postal_good'].isnull().sum()
# Out:
# 3527

# %%
## Managed to correct these postal codes
orders_df.loc[orders_df['postal_good'].notnull() & (orders_df['postal_valid']==False)][['customer_address_postal','postal_good']]
# Out:
#                     customer_address_postal postal_good
# 26                         Singapore 319400      319400
# 121                                 S570442      570442
# 133                        Singapore 570308      570308
# 446                                 567720       567720
# 575                                 530911       530911
# 593                        SINGAPORE 187969      187969
# 664           Marina Bay Residences, 018980      018980
# 703                                 S257889      257889
# 715                                  238843      238843
# 739                        Singapore 079908      079908
# 848                                 ​069543      069543
# 905                                 120453       120453
# 994                                 s828748      828748
# 1102                                S159052      159052
# 1216                                 636986      636986
# 1275            Aloha Loyang Resort S507020      507020
# 1293                                S518088      518088
# 1294                                138675       138675
# 1776                                640739       640739
# 1904                                339509       339509
# 2173                     Postal code 547325      547325
# 2255                                 269734      269734
# 2264                                469601       469601
# 2318                                 598102      598102
# 2469                                 068912      068912
# 2654                                 120206      120206
# 2874                       Singapore 138588      138588
# 2955                                S519599      519599
# 3080                                s159944      159944
# 3659       D'Resort @ Downtown East S519599      519599
# ...                                     ...         ...
# 15137                  21 Ocean Way S098374      098374
# 15173                  Postal code : 099200      099200
# 15338                               039594       039594
# 15433                                567720      567720
# 15667                               119918       119918
# 15696                                598435      598435
# 16521                                679946      679946
# 16634                      Singapore 609966      609966
# 17074                               535762       535762
# 17143                                649848      649848
# 17239                               S613138      613138
# 17579                             S(636986)      636986
# 17682  70 Biopolis Street, Singapore 138547      138547
# 17856                              169875        169875
# 18151                                598102      598102
# 18251                               138588       138588
# 18673                               680154       680154
# 18909                               S648151      648151
# 19166                      Singapore 119228      119228
# 19210                               069046       069046
# 19273               2 Netheravon Rd, 508503      508503
# 19302                               739000       739000
# 19443                               018989       018989
# 20217                               823226       823226
# 20225                                299323      299323
# 20298                                189556      189556
# 20636                               229616       229616
# 21107                               `409020      409020
# 21201                               s138567      138567
# 21419                               s138567      138567
#
# [147 rows x 2 columns]

# %% [markdown]
# <<Use the **postal_good** column >>>>

# %% [markdown]
# ### promotion_code

# %%
# Check types for 'promotion code'
orders_df['promotion_code'].value_counts()
#orders_df['promotion_code'].count()
## 2884 codes
## Clean out the ,
## Convert to UPPERCASE
# Out:
# FIRST10,            1093
# FRIENDS,             437
# FIRST5               428
# FIRST5,              360
# 10OFF,               151
# 1212,                 53
# GIVEMESALAD,          52
# UglyCakeKakis,        50
# 10OFF                 48
# WATG,                 26
# YayDads               19
# WELCOMEBACK,          12
# 5OFF50                11
# 4FLASH,               11
# FT12                  10
# 10                     9
# FlavourOfTheWeek       7
# HEALTHY10,             6
# 20YCE,                 6
# AACAKELOVE,            6
# HUNGRY4SC              6
# XMAS20,                5
# singtel,               5
# LIGHTBITES15,          5
# SG52,                  5
# CORPORATE,             5
# GSS3,                  4
# 5off50                 4
# 15,                    3
# Hungry4sc              3
#                     ...
# DimSumParty50,         1
# FF20,                  1
# cv20,                  1
# APRILGIVEAWAY,         1
# TanTanFriends          1
# SITJUNE2018            1
# xoddle10,              1
# ,FIRST10               1
# hungry4sc              1
# DND517,                1
# thankyoulele,          1
# VZC68B,                1
# FORMICH,               1
# TWDGIVEAWAY,           1
# 69JK71,                1
# GIVEAWAY4,             1
# NEW10,                 1
# WELCOMEBACK            1
# WINNIE2136,            1
# HappyKids              1
# DND604,                1
# healthy10,             1
# EATWU,                 1
# RAYA20                 1
# 4GIVEAWAY,             1
# thankyouLYNSS,         1
# FIRST20                1
# SweetOmbre             1
# DND852,                1
# NC20,                  1
# Name: promotion_code, Length: 69, dtype: int64

# %%
## Function to remove , and to convert all to UPPERCASE

def clean_promo(code):
    if type(code) == str:
        code = code.upper()
        code = code.replace(',','') ##remove ','
        return code
    else:
        return code ## Keep numeric codes and nulls

# %%
## Apply the function
orders_df['promo_good'] = orders_df['promotion_code'].apply(lambda x: clean_promo(x))

# %%
orders_df['promo_good'].value_counts()  ##Corrected the grouping counts
# Out:
# FIRST10               1094
# FIRST5                 788
# FRIENDS                437
# 10OFF                  200
# 1212                    53
# GIVEMESALAD             52
# UGLYCAKEKAKIS           50
# WATG                    26
# YAYDADS                 19
# 5OFF50                  15
# WELCOMEBACK             13
# 4FLASH                  11
# HUNGRY4SC               10
# FT12                    10
# 10                       9
# FLAVOUROFTHEWEEK         7
# HEALTHY10                7
# 20YCE                    6
# AACAKELOVE               6
# CORPORATE                5
# LIGHTBITES15             5
# SG52                     5
# SINGTEL                  5
# XMAS20                   5
# 15                       5
# GSS3                     4
# CV20                     3
# FT10                     3
# SINGAPORELICIOUZ10       2
# HEALTHYFOOD              2
# SITJUNE2018              1
# 69JK71                   1
# THANKYOULYNSS            1
# HAPPYBIRTHDAYCROWN       1
# DND604                   1
# DND852                   1
# A67DBG                   1
# VZC68B                   1
# TANTANFRIENDS            1
# XODDLE10                 1
# NC20                     1
# FORMICH                  1
# WINNIE2136               1
# GIVEAWAY4                1
# HAPPYKIDS                1
# APRILGIVEAWAY            1
# FF20                     1
# EATWU                    1
# 4GIVEAWAY                1
# DIMSUMPARTY50            1
# THANKYOULELE             1
# TWDGIVEAWAY              1
# DND517                   1
# SWEETOMBRE               1
# FIRST20                  1
# NEW10                    1
# RAYA20                   1
# Name: promo_good, dtype: int64

# %%
orders_df['promo_good'].count()
# Out:
# 2884

# %% [markdown]
# ### lead_time

# %%
orders_df['lead_time']
# Out:
# 0        2160.0
# 1          60.0
# 2        2880.0
# 3        4320.0
# 4         120.0
# 5          60.0
# 6         120.0
# 7        2880.0
# 8         120.0
# 9          60.0
# 10         60.0
# 11         60.0
# 12        120.0
# 13        120.0
# 14        120.0
# 15        120.0
# 16        120.0
# 17        120.0
# 18       2880.0
# 19        120.0
# 20         60.0
# 21         60.0
# 22       2160.0
# 23       4320.0
# 24        150.0
# 25       4320.0
# 26        120.0
# 27        150.0
# 28        120.0
# 29        120.0
#           ...
# 22091      90.0
# 22092     720.0
# 22093    2880.0
# 22094    2880.0
# 22095    4320.0
# 22096    4320.0
# 22097     720.0
# 22098     150.0
# 22099     150.0
# 22100     150.0
# 22101     720.0
# 22102      15.0
# 22103    4320.0
# 22104     720.0
# 22105      20.0
# 22106     150.0
# 22107     720.0
# 22108      90.0
# 22109    4320.0
# 22110      90.0
# 22111     120.0
# 22112     120.0
# 22113    4320.0
# 22114      90.0
# 22115     720.0
# 22116     150.0
# 22117      30.0
# 22118     150.0
# 22119      30.0
# 22120      90.0
# Name: lead_time, Length: 22121, dtype: float64

# %%
orders_df['lead_time'].max()
# Out:
# 4320.0

# %%
orders_df['lead_time'].min()
# Out:
# 0.0

# %%
## Check orders with NO LEAD TIME
orders_df.loc[orders_df['lead_time']==0]

## Merchants that dont have lead time, 1 Cake and the Salad
# Out:
#              submitted_on  pickup       delivery_date customer_address_postal  \
# 474   2017-01-04 09:15:06       0 2017-01-07 09:30:00                     NaN
# 569   2017-12-08 02:27:39       0 2017-12-08 03:30:00                  349327
# 618   2017-12-14 05:36:26       0 2017-12-15 03:30:00                  537055
# 707   2018-02-02 00:46:13       0 2018-02-02 03:30:00                  408931
# 712   2018-02-02 02:18:34       0 2018-02-02 03:30:00                  408734
# 781   2018-02-05 21:24:52       0 2018-02-06 03:30:00                  408734
# 783   2018-02-07 02:06:59       0 2018-02-07 03:30:00                  408538
# 829   2018-02-06 12:59:21       0 2018-02-07 03:30:00                  408931
# 841   2018-02-07 11:57:17       0 2018-02-08 03:30:00                  408931
# 846   2018-02-12 09:54:54       0 2018-02-13 03:30:00                  408538
# 849   2018-02-06 01:58:24       0 2018-02-06 03:30:00                  408868
# 881   2018-02-08 00:43:06       0 2018-02-08 03:30:00                  374018
# 1760  2018-03-01 03:23:32       0 2018-03-02 03:30:00                  400319
# 1791  2018-02-27 12:47:20       0 2018-02-28 03:30:00                  408931
# 1807  2018-02-26 02:14:23       0 2018-02-26 03:30:00                  408538
# 1811  2018-02-26 02:04:24       0 2018-02-26 03:30:00                  408868
# 1813  2018-02-26 06:12:51       0 2018-02-27 03:30:00                  408931
# 1815  2018-02-26 13:07:15       0 2018-02-27 03:30:00                  537846
# 2900  2018-02-11 21:24:24       0 2018-02-12 03:30:00                  408931
# 3012  2018-01-26 01:22:54       0 2018-01-26 03:30:00                  349485
# 3013  2018-01-26 02:05:11       0 2018-01-26 03:30:00                  349485
# 3018  2018-02-01 01:19:10       0 2018-02-01 03:30:00                  368240
# 3385  2018-01-29 00:21:56       0 2018-01-29 03:30:00                  408538
# 3421  2018-01-25 00:56:40       0 2018-01-25 03:30:00                  408538
# 3423  2018-01-25 01:18:54       0 2018-01-25 03:30:00                  408868
# 3425  2018-01-25 01:55:15       0 2018-01-25 03:30:00                  536208
# 4720  2018-02-27 02:21:14       0 2018-02-27 03:30:00                  408868
# 5085  2018-03-01 00:21:52       0 2018-03-01 03:30:00                  408538
# 8915  2017-11-21 01:58:58       0 2017-11-21 03:30:00                  408538
# 8971  2017-11-06 02:18:55       0 2017-11-06 03:30:00                  408868
# 9033  2017-11-07 02:11:48       0 2017-11-07 03:30:00                  408868
# 9036  2017-11-07 03:57:19       0 2017-11-08 03:30:00                  537055
# 9041  2017-11-08 07:08:57       0 2017-11-09 03:30:00                  537055
# 9086  2017-11-13 06:37:09       0 2017-11-14 03:30:00                  537055
# 9110  2018-02-08 02:08:31       0 2018-02-08 03:30:00                  536208
# 9114  2018-02-08 14:04:35       0 2018-02-09 03:30:00                  408931
# 9124  2018-02-08 02:10:52       0 2018-02-08 03:30:00                  408538
# 9125  2018-02-07 02:12:17       0 2018-02-07 03:30:00                  408868
# 9166  2018-02-07 23:33:25       0 2018-02-08 03:30:00                  408734
# 9173  2018-02-13 01:29:10       0 2018-02-13 03:30:00                  408538
# 9179  2018-02-09 01:05:18       0 2018-02-09 03:30:00                  374018
# 11563 2018-01-25 23:12:58       0 2018-01-26 03:30:00                  408734
# 11904 2017-11-19 04:14:52       0 2017-11-20 03:30:00                  535215
# 11922 2017-11-20 01:43:05       0 2017-11-20 03:30:00                  408868
# 11930 2017-11-20 03:54:59       0 2017-11-21 03:30:00                  537055
# 11938 2017-11-21 02:03:52       0 2017-11-21 03:30:00                  349327
# 11970 2017-11-21 07:15:03       0 2017-11-22 03:30:00                  537055
# 11972 2017-12-08 02:29:05       0 2017-12-08 03:30:00                  408538
# 12203 2018-02-25 08:06:41       0 2018-02-26 03:30:00                  408931
# 13193 2018-01-31 21:35:38       0 2018-02-01 03:30:00                  408931
# 13196 2018-02-01 00:45:41       0 2018-02-01 03:30:00                  408538
# 15354 2017-11-13 02:16:26       0 2017-11-13 03:30:00                  408868
# 15375 2017-11-14 07:04:18       0 2017-11-15 03:30:00                  537055
# 16579 2017-11-16 04:45:40       0 2017-11-17 03:30:00                  408538
# 17178 2018-03-07 02:15:27       0 2018-03-07 03:30:00                  408734
# 18948 2018-02-06 00:50:43       0 2018-02-06 03:30:00                  408538
# 19001 2018-01-30 00:49:57       0 2018-01-30 03:30:00                  408538
# 19005 2018-01-30 02:37:34       0 2018-01-31 03:30:00                  534167
# 19011 2018-01-31 14:46:16       0 2018-02-01 03:30:00                  408734
# 19027 2018-01-30 09:13:01       0 2018-01-31 03:30:00                  408931
#
#       promotion_code  lead_time  basket_size  customer_index  menu_id  \
# 474              NaN        0.0        98.63           21300        3
# 569              NaN        0.0        16.10             105        7
# 618              NaN        0.0        22.28             201        7
# 707              NaN        0.0        18.21             372        7
# 712              NaN        0.0        10.84               8        7
# 781              NaN        0.0        14.28               8        7
# 783              NaN        0.0        13.51             183        7
# 829              NaN        0.0        13.70             372        7
# 841              NaN        0.0        16.64             372        7
# 846              NaN        0.0        29.81               6        7
# 849              NaN        0.0        14.19             198        7
# 881              NaN        0.0        13.49               3        7
# 1760             NaN        0.0        13.06              15        7
# 1791             NaN        0.0        16.25             372        7
# 1807             NaN        0.0        17.00             183        7
# 1811             NaN        0.0        15.37             198        7
# 1813             NaN        0.0        75.10             372        7
# 1815             NaN        0.0        10.29              16        7
# 2900             NaN        0.0        15.40             372        7
# 3012             NaN        0.0        11.01             417        7
# 3013             NaN        0.0        14.59             417        7
# 3018             NaN        0.0        16.72             126        7
# 3385             NaN        0.0        15.17               6        7
# 3421             NaN        0.0        13.71             183        7
# 3423             NaN        0.0        19.34             198        7
# 3425             NaN        0.0        13.42              48        7
# 4720             NaN        0.0        19.37             198        7
# 5085             NaN        0.0        21.65               6        7
# 8915             NaN        0.0        46.85             183        7
# 8971             NaN        0.0        18.20             198        7
# 9033             NaN        0.0        18.66             198        7
# 9036             NaN        0.0        15.95             201        7
# 9041             NaN        0.0        15.78             201        7
# 9086             NaN        0.0        21.84             201        7
# 9110             NaN        0.0        17.84              48        7
# 9114             NaN        0.0        13.50             372        7
# 9124             NaN        0.0        16.16             183        7
# 9125             NaN        0.0        19.61             198        7
# 9166             NaN        0.0        16.73               8        7
# 9173             NaN        0.0        13.62             183        7
# 9179             NaN        0.0        14.77               3        7
# 11563            NaN        0.0        14.64               8        7
# 11904            NaN        0.0        72.31             259        7
# 11922            NaN        0.0        17.17             198        7
# 11930            NaN        0.0        14.64             201        7
# 11938            NaN        0.0        24.29             105        7
# 11970            NaN        0.0        15.87             201        7
# 11972            NaN        0.0        15.02             183        7
# 12203            NaN        0.0        13.41             372        7
# 13193            NaN        0.0        18.22             372        7
# 13196            NaN        0.0        14.77             183        7
# 15354            NaN        0.0        19.98             198        7
# 15375            NaN        0.0        15.71             201        7
# 16579            NaN        0.0        45.71             183        7
# 17178            NaN        0.0        14.51               8        7
# 18948            NaN        0.0        29.08               6        7
# 19001            NaN        0.0        21.25             183        7
# 19005            NaN        0.0        19.35             461        7
# 19011            NaN        0.0        14.46               8        7
# 19027            NaN        0.0        19.96             372        7
#
#       merchant_type  organisation_name_provided  postal_valid postal_good  \
# 474           Cakes                         0.0         False         NaN
# 569           Salad                         1.0          True      349327
# 618           Salad                         0.0          True      537055
# 707           Salad                         0.0          True      408931
# 712           Salad                         1.0          True      408734
# 781           Salad                         1.0          True      408734
# 783           Salad                         0.0          True      408538
# 829           Salad                         0.0          True      408931
# 841           Salad                         0.0          True      408931
# 846           Salad                         0.0          True      408538
# 849           Salad                         1.0          True      408868
# 881           Salad                         0.0          True      374018
# 1760          Salad                         0.0          True      400319
# 1791          Salad                         0.0          True      408931
# 1807          Salad                         0.0          True      408538
# 1811          Salad                         1.0          True      408868
# 1813          Salad                         0.0          True      408931
# 1815          Salad                         0.0          True      537846
# 2900          Salad                         0.0          True      408931
# 3012          Salad                         0.0          True      349485
# 3013          Salad                         0.0          True      349485
# 3018          Salad                         0.0          True      368240
# 3385          Salad                         0.0          True      408538
# 3421          Salad                         0.0          True      408538
# 3423          Salad                         0.0          True      408868
# 3425          Salad                         0.0          True      536208
# 4720          Salad                         1.0          True      408868
# 5085          Salad                         0.0          True      408538
# 8915          Salad                         0.0          True      408538
# 8971          Salad                         0.0          True      408868
# 9033          Salad                         0.0          True      408868
# 9036          Salad                         0.0          True      537055
# 9041          Salad                         0.0          True      537055
# 9086          Salad                         0.0          True      537055
# 9110          Salad                         0.0          True      536208
# 9114          Salad                         0.0          True      408931
# 9124          Salad                         0.0          True      408538
# 9125          Salad                         1.0          True      408868
# 9166          Salad                         1.0          True      408734
# 9173          Salad                         0.0          True      408538
# 9179          Salad                         0.0          True      374018
# 11563         Salad                         1.0          True      408734
# 11904         Salad                         1.0          True      535215
# 11922         Salad                         0.0          True      408868
# 11930         Salad                         0.0          True      537055
# 11938         Salad                         1.0          True      349327
# 11970         Salad                         0.0          True      537055
# 11972         Salad                         0.0          True      408538
# 12203         Salad                         0.0          True      408931
# 13193         Salad                         0.0          True      408931
# 13196         Salad                         0.0          True      408538
# 15354         Salad                         0.0          True      408868
# 15375         Salad                         0.0          True      537055
# 16579         Salad                         0.0          True      408538
# 17178         Salad                         1.0          True      408734
# 18948         Salad                         0.0          True      408538
# 19001         Salad                         0.0          True      408538
# 19005         Salad                         0.0          True      534167
# 19011         Salad                         1.0          True      408734
# 19027         Salad                         0.0          True      408931
#
#       promo_good
# 474          NaN
# 569          NaN
# 618          NaN
# 707          NaN
# 712          NaN
# 781          NaN
# 783          NaN
# 829          NaN
# 841          NaN
# 846          NaN
# 849          NaN
# 881          NaN
# 1760         NaN
# 1791         NaN
# 1807         NaN
# 1811         NaN
# 1813         NaN
# 1815         NaN
# 2900         NaN
# 3012         NaN
# 3013         NaN
# 3018         NaN
# 3385         NaN
# 3421         NaN
# 3423         NaN
# 3425         NaN
# 4720         NaN
# 5085         NaN
# 8915         NaN
# 8971         NaN
# 9033         NaN
# 9036         NaN
# 9041         NaN
# 9086         NaN
# 9110         NaN
# 9114         NaN
# 9124         NaN
# 9125         NaN
# 9166         NaN
# 9173         NaN
# 9179         NaN
# 11563        NaN
# 11904        NaN
# 11922        NaN
# 11930        NaN
# 11938        NaN
# 11970        NaN
# 11972        NaN
# 12203        NaN
# 13193        NaN
# 13196        NaN
# 15354        NaN
# 15375        NaN
# 16579        NaN
# 17178        NaN
# 18948        NaN
# 19001        NaN
# 19005        NaN
# 19011        NaN
# 19027        NaN

# %%
orders_df['lead_time'].isnull().sum()

# 1 Null
# Out:
# 1

# %%
orders_df.loc[orders_df['lead_time'].isnull()]
# Out:
#              submitted_on  pickup       delivery_date customer_address_postal  \
# 12821 2018-04-25 12:22:00       1 2018-04-30 09:00:00                     NaN
#
#       promotion_code  lead_time  basket_size  customer_index  menu_id  \
# 12821            NaN        NaN       123.73           46748        4
#
#       merchant_type  organisation_name_provided  postal_valid postal_good  \
# 12821         Cakes                         0.0         False         NaN
#
#       promo_good
# 12821        NaN

# %%
orders_df.loc[orders_df['lead_time'].isnull()]['delivery_date'] - orders_df.loc[orders_df['lead_time'].isnull()]['submitted_on']
# Out:
# 12821   4 days 20:38:00
# dtype: timedelta64[ns]

# %%
## to be safe we impute with the Max lead time of 3 days. (4320 mins)
x = orders_df[orders_df['lead_time'].isnull()]

orders_df.loc[x.index, 'lead_time'] = 4320.0

# %%
orders_df.loc[orders_df['lead_time'].isnull()] ##Check for replacement done.
# Out:
# Empty DataFrame
# Columns: [submitted_on, pickup, delivery_date, customer_address_postal, promotion_code, lead_time, basket_size, customer_index, menu_id, merchant_type, organisation_name_provided, postal_valid, postal_good, promo_good]
# Index: []

# %%
## Function to convert the minutes into days/hrs/min for easier viewing

def fix_time(time):
    hrs, mins = divmod(time, 60)
    days, hrs = divmod(hrs, 24)
    #print ("%d:%02d:%02d" % (days, hrs, mins))
    return ("%d:%02d:%02d" % (days, hrs, mins))

# %%
orders_df['lead_time_good'] = orders_df['lead_time'].apply(lambda x: fix_time(x))

# %%
orders_df['lead_time_good'].value_counts()

## We can see the groupings for the leadtimes (In a way to bin the lead times)
# Out:
# 0:02:30    4450
# 0:12:00    4052
# 2:00:00    3351
# 3:00:00    2772
# 0:01:30    2227
# 0:01:00    2067
# 0:02:00     929
# 0:00:20     698
# 1:12:00     454
# 0:00:30     392
# 0:00:15     352
# 0:00:25     222
# 0:00:45      62
# 0:00:00      60
# 0:00:10      21
# 0:00:55       5
# 0:03:00       4
# 2:00:30       1
# 1:12:30       1
# 0:18:00       1
# Name: lead_time_good, dtype: int64

# %% [markdown]
# ### basket_size

# %%
# Check for nulls
orders_df['basket_size'].isnull().sum()
# Out:
# 0

# %%
import decimal

# %%
def check_decimals(basket):
    d = decimal.Decimal(str(basket)) ##Cast back into string
    dp = d.as_tuple().exponent
    #print(dp)
    if dp < -2:
        print(dp)
        return False
    else:
        return True

# %%
orders_df['basket_valid'] = orders_df['basket_size'].apply(lambda x: check_decimals(x))

# %%
orders_df['basket_valid'].value_counts()
# Out:
# True    22121
# Name: basket_valid, dtype: int64

# %%
orders_df['basket_size'].max()

##Looks abit suspicious
# Out:
# 99999.0

# %%
orders_df['basket_size'].min()
# Out:
# 3.01

# %%
## Lets view the basket_size distribution
orders_df['basket_size'].sort_values(ascending=False)
# Out:
# 4145     99999.00
# 4180     99999.00
# 4170     99999.00
# 4171     99999.00
# 4172     99999.00
# 4173     99999.00
# 4174     99999.00
# 4175     99999.00
# 4176     99999.00
# 4177     99999.00
# 4178     99999.00
# 4179     99999.00
# 4181     99999.00
# 4192     99999.00
# 4182     99999.00
# 4183     99999.00
# 4184     99999.00
# 4185     99999.00
# 4186     99999.00
# 4187     99999.00
# 4244     99999.00
# 4188     99999.00
# 4189     99999.00
# 4190     99999.00
# 4169     99999.00
# 4168     99999.00
# 4167     99999.00
# 4166     99999.00
# 4147     99999.00
# 4148     99999.00
#            ...
# 785          4.68
# 5021         4.65
# 10078        4.64
# 21360        4.60
# 9599         4.55
# 21181        4.47
# 4046         4.41
# 10866        4.34
# 9796         4.33
# 9650         4.27
# 12160        4.23
# 1255         4.21
# 4558         4.19
# 1519         4.05
# 14992        4.02
# 11083        3.95
# 15410        3.93
# 11079        3.93
# 18657        3.90
# 1658         3.87
# 15055        3.72
# 13289        3.68
# 4560         3.60
# 17137        3.54
# 617          3.43
# 184          3.38
# 1653         3.38
# 17450        3.12
# 1829         3.02
# 4545         3.01
# Name: basket_size, Length: 22121, dtype: float64

# %%
orders_df.groupby(by='basket_size').count()
# Out:
#              submitted_on  pickup  delivery_date  customer_address_postal  \
# basket_size
# 3.01                    1       1              1                        1
# 3.02                    1       1              1                        0
# 3.12                    1       1              1                        1
# 3.38                    2       2              2                        0
# 3.43                    1       1              1                        0
# 3.54                    1       1              1                        0
# 3.60                    1       1              1                        0
# 3.68                    1       1              1                        1
# 3.72                    1       1              1                        0
# 3.87                    1       1              1                        0
# 3.90                    1       1              1                        0
# 3.93                    2       2              2                        1
# 3.95                    1       1              1                        0
# 4.02                    1       1              1                        0
# 4.05                    1       1              1                        1
# 4.19                    1       1              1                        0
# 4.21                    1       1              1                        1
# 4.23                    1       1              1                        0
# 4.27                    1       1              1                        1
# 4.33                    1       1              1                        1
# 4.34                    1       1              1                        1
# 4.41                    1       1              1                        0
# 4.47                    1       1              1                        1
# 4.55                    1       1              1                        1
# 4.60                    1       1              1                        0
# 4.64                    1       1              1                        1
# 4.65                    1       1              1                        0
# 4.68                    1       1              1                        1
# 4.72                    1       1              1                        1
# 4.80                    2       2              2                        1
# ...                   ...     ...            ...                      ...
# 827.07                  1       1              1                        1
# 847.05                  1       1              1                        0
# 855.02                  1       1              1                        1
# 856.59                  1       1              1                        1
# 876.41                  1       1              1                        1
# 890.40                  1       1              1                        1
# 898.60                  1       1              1                        1
# 902.20                  1       1              1                        1
# 914.00                  1       1              1                        1
# 934.38                  1       1              1                        1
# 936.78                  1       1              1                        1
# 944.62                  1       1              1                        1
# 960.45                  1       1              1                        1
# 997.58                  1       1              1                        1
# 1002.91                 1       1              1                        1
# 1008.92                 1       1              1                        1
# 1027.61                 1       1              1                        1
# 1157.15                 1       1              1                        1
# 1174.10                 1       1              1                        1
# 1199.65                 1       1              1                        1
# 1203.76                 1       1              1                        1
# 1211.03                 1       1              1                        1
# 1260.59                 1       1              1                        1
# 1333.88                 1       1              1                        1
# 1598.92                 1       1              1                        1
# 1683.07                 1       1              1                        1
# 1700.89                 1       1              1                        1
# 1975.87                 1       1              1                        1
# 3092.27                 1       1              1                        1
# 99999.00              199     199            199                      171
#
#              promotion_code  lead_time  customer_index  menu_id  \
# basket_size
# 3.01                      0          1               1        1
# 3.02                      0          1               1        1
# 3.12                      0          1               1        1
# 3.38                      0          2               2        2
# 3.43                      0          1               1        1
# 3.54                      0          1               1        1
# 3.60                      0          1               1        1
# 3.68                      0          1               1        1
# 3.72                      0          1               1        1
# 3.87                      0          1               1        1
# 3.90                      0          1               1        1
# 3.93                      0          2               2        2
# 3.95                      0          1               1        1
# 4.02                      0          1               1        1
# 4.05                      0          1               1        1
# 4.19                      0          1               1        1
# 4.21                      0          1               1        1
# 4.23                      0          1               1        1
# 4.27                      0          1               1        1
# 4.33                      0          1               1        1
# 4.34                      0          1               1        1
# 4.41                      0          1               1        1
# 4.47                      0          1               1        1
# 4.55                      0          1               1        1
# 4.60                      0          1               1        1
# 4.64                      0          1               1        1
# 4.65                      0          1               1        1
# 4.68                      0          1               1        1
# 4.72                      0          1               1        1
# 4.80                      1          2               2        2
# ...                     ...        ...             ...      ...
# 827.07                    0          1               1        1
# 847.05                    0          1               1        1
# 855.02                    0          1               1        1
# 856.59                    0          1               1        1
# 876.41                    1          1               1        1
# 890.40                    0          1               1        1
# 898.60                    1          1               1        1
# 902.20                    0          1               1        1
# 914.00                    0          1               1        1
# 934.38                    0          1               1        1
# 936.78                    0          1               1        1
# 944.62                    0          1               1        1
# 960.45                    0          1               1        1
# 997.58                    0          1               1        1
# 1002.91                   0          1               1        1
# 1008.92                   0          1               1        1
# 1027.61                   0          1               1        1
# 1157.15                   0          1               1        1
# 1174.10                   0          1               1        1
# 1199.65                   0          1               1        1
# 1203.76                   0          1               1        1
# 1211.03                   0          1               1        1
# 1260.59                   0          1               1        1
# 1333.88                   0          1               1        1
# 1598.92                   0          1               1        1
# 1683.07                   0          1               1        1
# 1700.89                   0          1               1        1
# 1975.87                   0          1               1        1
# 3092.27                   0          1               1        1
# 99999.00                 28        199             199      199
#
#              merchant_type  organisation_name_provided  postal_valid  \
# basket_size
# 3.01                     1                           1             1
# 3.02                     1                           1             1
# 3.12                     1                           1             1
# 3.38                     2                           2             2
# 3.43                     1                           1             1
# 3.54                     1                           1             1
# 3.60                     1                           1             1
# 3.68                     1                           1             1
# 3.72                     1                           1             1
# 3.87                     1                           1             1
# 3.90                     1                           1             1
# 3.93                     2                           2             2
# 3.95                     1                           1             1
# 4.02                     1                           1             1
# 4.05                     1                           1             1
# 4.19                     1                           1             1
# 4.21                     1                           1             1
# 4.23                     1                           1             1
# 4.27                     1                           1             1
# 4.33                     1                           1             1
# 4.34                     1                           1             1
# 4.41                     1                           1             1
# 4.47                     1                           1             1
# 4.55                     1                           1             1
# 4.60                     1                           1             1
# 4.64                     1                           1             1
# 4.65                     1                           1             1
# 4.68                     1                           1             1
# 4.72                     1                           1             1
# 4.80                     2                           2             2
# ...                    ...                         ...           ...
# 827.07                   1                           1             1
# 847.05                   1                           1             1
# 855.02                   1                           1             1
# 856.59                   1                           1             1
# 876.41                   1                           1             1
# 890.40                   1                           1             1
# 898.60                   1                           1             1
# 902.20                   1                           1             1
# 914.00                   1                           1             1
# 934.38                   1                           1             1
# 936.78                   1                           1             1
# 944.62                   1                           1             1
# 960.45                   1                           1             1
# 997.58                   1                           1             1
# 1002.91                  1                           1             1
# 1008.92                  1                           1             1
# 1027.61                  1                           1             1
# 1157.15                  1                           1             1
# 1174.10                  1                           1             1
# 1199.65                  1                           1             1
# 1203.76                  1                           1             1
# 1211.03                  1                           1             1
# 1260.59                  1                           1             1
# 1333.88                  1                           1             1
# 1598.92                  1                           1             1
# 1683.07                  1                           1             1
# 1700.89                  1                           1             1
# 1975.87                  1                           1             1
# 3092.27                  1                           1             1
# 99999.00               199                         199           199
#
#              postal_good  promo_good  lead_time_good  basket_valid
# basket_size
# 3.01                   1           0               1             1
# 3.02                   0           0               1             1
# 3.12                   1           0               1             1
# 3.38                   0           0               2             2
# 3.43                   0           0               1             1
# 3.54                   0           0               1             1
# 3.60                   0           0               1             1
# 3.68                   1           0               1             1
# 3.72                   0           0               1             1
# 3.87                   0           0               1             1
# 3.90                   0           0               1             1
# 3.93                   1           0               2             2
# 3.95                   0           0               1             1
# 4.02                   0           0               1             1
# 4.05                   1           0               1             1
# 4.19                   0           0               1             1
# 4.21                   1           0               1             1
# 4.23                   0           0               1             1
# 4.27                   1           0               1             1
# 4.33                   1           0               1             1
# 4.34                   1           0               1             1
# 4.41                   0           0               1             1
# 4.47                   1           0               1             1
# 4.55                   1           0               1             1
# 4.60                   0           0               1             1
# 4.64                   1           0               1             1
# 4.65                   0           0               1             1
# 4.68                   1           0               1             1
# 4.72                   1           0               1             1
# 4.80                   1           1               2             2
# ...                  ...         ...             ...           ...
# 827.07                 1           0               1             1
# 847.05                 0           0               1             1
# 855.02                 1           0               1             1
# 856.59                 1           0               1             1
# 876.41                 1           1               1             1
# 890.40                 1           0               1             1
# 898.60                 1           1               1             1
# 902.20                 1           0               1             1
# 914.00                 1           0               1             1
# 934.38                 1           0               1             1
# 936.78                 1           0               1             1
# 944.62                 1           0               1             1
# 960.45                 1           0               1             1
# 997.58                 1           0               1             1
# 1002.91                1           0               1             1
# 1008.92                1           0               1             1
# 1027.61                1           0               1             1
# 1157.15                1           0               1             1
# 1174.10                1           0               1             1
# 1199.65                1           0               1             1
# 1203.76                1           0               1             1
# 1211.03                1           0               1             1
# 1260.59                1           0               1             1
# 1333.88                1           0               1             1
# 1598.92                1           0               1             1
# 1683.07                0           0               1             1
# 1700.89                1           0               1             1
# 1975.87                1           0               1             1
# 3092.27                1           0               1             1
# 99999.00             170          28             199           199
#
# [13129 rows x 15 columns]

# %%
orders_df.loc[orders_df['basket_size']== 99999.00]
## We will have to drop these entries, as they are invalid

orders_df.loc[orders_df['basket_size']== 99999.00].index
# Out:
# Int64Index([4056, 4057, 4058, 4059, 4060, 4061, 4062, 4063, 4064, 4065,
#             ...
#             4245, 4246, 4247, 4248, 4249, 4250, 4251, 4252, 4253, 4254],
#            dtype='int64', length=199)

# %% [markdown]
# ### basket size imputation to consider later (Not run)

# %% [markdown]
# #### Option 1: Create a new feature that imputes the 99999.0 and replaces it with the median of the merchant's basket size

# %%
## We use the median to impute because the mean may be skewed by the rare-occasion large basket.
## Taking the median is a safer approach

# %% [markdown]
# #### Option 2: Dropping 199 rows.

# %%
## We can afford to drop the 199 rows of data as it is less than 1% of our dataset.
(199/22121)*100

# %%
## Drop invalid basket sizes
orders_df.drop(orders_df.loc[orders_df['basket_size']== 99999.00].index, axis=0, inplace=True)

# %%
orders_df['basket_size'].sort_values(ascending=False)

# %% [markdown]
# ### customer_index

# %%
orders_df['customer_index'].isnull().sum()

## No nulls for customer_id
## Check for validity later
# Out:
# 0

# %% [markdown]
# ### menu_id & merchant_type

# %%
orders_df['menu_id'].isnull().sum()
## No nulls for menu id
# Out:
# 0

# %%
## Convert Data type for menu_id to int64
orders_df['menu_id'] = orders_df['menu_id'].astype(int)

# %%
## Menu_id must match up with merchant_type
orders_df['menu_id'].value_counts()
# Out:
# 5    5363
# 1    4507
# 2    4312
# 3    3354
# 4    2776
# 6    1566
# 8     141
# 7     102
# Name: menu_id, dtype: int64

# %%
orders_df['menu_id'].unique()

## We have menus 1-8
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
orders_df['merchant_type'].isnull().sum()
# Out:
# 0

# %%
orders_df['merchant_type'].count()
# Out:
# 22121

# %%
orders_df['merchant_type'].value_counts()
# Out:
# Cakes             10637
# Dim Sum            5504
# Korean Chicken     4312
# Salad              1668
# Name: merchant_type, dtype: int64

# %%
## Check for ids for CAKES
orders_df.loc[orders_df['merchant_type']=='Cakes']['menu_id'].unique()
# Out:
# array([1, 3, 4])

# %%
## Check for ids for DIM SUM
orders_df.loc[orders_df['merchant_type']=='Dim Sum']['menu_id'].unique()
# Out:
# array([5, 8])

# %%
## Check for ids for KOREAN CHICKEN
orders_df.loc[orders_df['merchant_type']=='Korean Chicken']['menu_id'].unique()
# Out:
# array([2])

# %%
## Check for ids for SALAD
orders_df.loc[orders_df['merchant_type']=='Salad']['menu_id'].unique()
# Out:
# array([6, 7])

# %% [markdown]
# **Merchant Menu ids to their types**
# <table style="height: 95px;" border="1" width="281">
# <tbody>
# <tr>
# <td style="width: 173px;">Cakes</td>
# <td style="width: 92px;">1 , 3 , 4</td>
# </tr>
# <tr>
# <td style="width: 173px;">Dim Sum</td>
# <td style="width: 92px;">5 , 8</td>
# </tr>
# <tr>
# <td style="width: 173px;">Korean Chicken</td>
# <td style="width: 92px;">2</td>
# </tr>
# <tr>
# <td style="width: 173px;">Salad</td>
# <td style="width: 92px;">6 , 7</td>
# </tr>
# </tbody>
# </table>

# %%
## Check for match up for amount of merchants_types to the ids

## The total amount of menu_ids of 1, 3 and 4 must == merchant_type Cakes count of 10637
orders_df.loc[(orders_df['menu_id'].isin([1,3,4]))]['merchant_type'].count()
# Out:
# 10637

# %%
## example: The total amount of menu_ids of 5 and 8 must == merchant_type Dim Sum count of 5504
orders_df.loc[(orders_df['menu_id'].isin([5,8]))]['merchant_type'].count()
# Out:
# 5504

# %%
## example: The total amount of menu_ids of 2 must == merchant_type Korean Chicken count of 4312
orders_df.loc[(orders_df['menu_id'].isin([2]))]['merchant_type'].count()
# Out:
# 4312

# %%
## example: The total amount of menu_ids of 2 must == merchant_type Salad count of 1668
orders_df.loc[(orders_df['menu_id'].isin([6,7]))]['merchant_type'].count()
# Out:
# 1668

# %%
orders_df.loc[(orders_df['menu_id'].isin([6,7])) & (orders_df['basket_size'] != 99999.0)]['basket_size'].sum()
# Out:
# 214306.02

# %%
orders_df['promo_good'].notnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12        True
# 13       False
# 14        True
# 15        True
# 16       False
# 17        True
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27        True
# 28       False
# 29       False
#          ...
# 22091    False
# 22092    False
# 22093    False
# 22094    False
# 22095     True
# 22096     True
# 22097    False
# 22098    False
# 22099    False
# 22100    False
# 22101    False
# 22102    False
# 22103     True
# 22104    False
# 22105    False
# 22106    False
# 22107    False
# 22108    False
# 22109    False
# 22110    False
# 22111     True
# 22112     True
# 22113     True
# 22114    False
# 22115    False
# 22116    False
# 22117    False
# 22118    False
# 22119    False
# 22120    False
# Name: promo_good, Length: 22121, dtype: bool

# %%
orders_df.loc[(orders_df['menu_id'].isin([5])) & (orders_df['basket_size'] != 99999.0) & (orders_df['promo_good'].notnull())]['basket_size'].sum()
# Out:
# 220188.31

# %% [markdown]
# ### organisation_name_provided

# %%
orders_df['organisation_name_provided'].isnull().sum()

## has 7 nulls.
# Out:
# 7

# %%
orders_df[orders_df['organisation_name_provided'].isnull()]
# Out:
#              submitted_on  pickup       delivery_date customer_address_postal  \
# 3903  2018-06-11 08:43:15       1 2018-06-13 04:00:00                     NaN
# 6741  2017-08-10 02:35:17       0 2017-08-12 08:30:00                  731899
# 10327 2018-06-04 06:14:26       1 2018-06-09 04:00:00                     NaN
# 13446 2018-05-25 06:00:35       1 2018-05-26 04:00:00                     NaN
# 15275 2017-08-02 00:15:11       0 2017-08-07 10:30:00                  520142
# 19595 2018-08-09 05:20:52       1 2018-08-25 06:00:00                     NaN
# 21142 2018-09-11 02:47:36       0 2018-09-15 04:00:00                  178897
#
#       promotion_code  lead_time  basket_size  customer_index  menu_id  \
# 3903             NaN      720.0        67.32           29703        1
# 6741             NaN     2880.0       143.20           23043        3
# 10327            NaN      720.0       138.26           32980        1
# 13446            NaN      720.0        95.59           32980        1
# 15275            NaN     2880.0        76.80           25752        3
# 19595            NaN     4320.0        48.19           49359        4
# 21142            NaN      720.0        77.99           32844        1
#
#       merchant_type  organisation_name_provided  postal_valid postal_good  \
# 3903          Cakes                         NaN         False         NaN
# 6741          Cakes                         NaN          True      731899
# 10327         Cakes                         NaN         False         NaN
# 13446         Cakes                         NaN         False         NaN
# 15275         Cakes                         NaN          True      520142
# 19595         Cakes                         NaN         False         NaN
# 21142         Cakes                         NaN          True      178897
#
#       promo_good lead_time_good  basket_valid
# 3903         NaN        0:12:00          True
# 6741         NaN        2:00:00          True
# 10327        NaN        0:12:00          True
# 13446        NaN        0:12:00          True
# 15275        NaN        2:00:00          True
# 19595        NaN        3:00:00          True
# 21142        NaN        0:12:00          True

# %%
## Since organisation_name_provided is a binary. We will impute all NaNs with 0

x = orders_df[orders_df['organisation_name_provided'].isnull()]

orders_df.loc[x.index, 'organisation_name_provided'] = 0

# %%
## Recheck for the Nulls
orders_df['organisation_name_provided'].isnull().sum()
# Out:
# 0

# %%
orders_df['organisation_name_provided'] = orders_df['organisation_name_provided'].astype(int)

# %%
orders_df['organisation_name_provided'].value_counts()
## We have 4001 orders for organizations
# Out:
# 0    18120
# 1     4001
# Name: organisation_name_provided, dtype: int64

# %% [markdown]
# <hr>

# %%
#Check data types
orders_df.dtypes
# Out:
# submitted_on                  datetime64[ns]
# pickup                                 int64
# delivery_date                 datetime64[ns]
# customer_address_postal               object
# promotion_code                        object
# lead_time                            float64
# basket_size                          float64
# customer_index                         int64
# menu_id                                int64
# merchant_type                         object
# organisation_name_provided             int64
# postal_valid                            bool
# postal_good                           object
# promo_good                            object
# lead_time_good                        object
# basket_valid                            bool
# dtype: object

# %% [markdown]
# ## Export  'cleaned' Orders dataset

# %%
orders_df.to_csv('orders_cleaned.csv')
## Exported out for Viz and further use

# %% [markdown]
# # Summary of Orders dataset

# %% [markdown]
# - The dataset consist of **22121 observations (rows) 11 Features (cols)**
# - customer_address_postal has 3371 nulls
# - promotion_code has 19237 nulls
# - organisation_Name_provided has 7 nulls
# - This dataset spans from **2016-10-01** to **2018-09-30**
#
# <b>From the data dictionary provided in the Assignment PDF</b>
# - submitted_on == Date Time for order submission
# - pickup == 1/0 binary
# - delivery_date == Date Time
# - customer_address_postal   == String -> need to convert to 6 digit integer
# - promotion_code == String obj
# - lead_time == integer (No. of mins) -> Might convert to time object
# - basket_size  == float ($$ worth of basket)
# - customer_index == customer ID, unique integer (Match from customer table)
# - menu_id == Merchant ID
# - merchant_type == String obj categorical
# - organisation_name_provided == binary 1/0 (Corporate or not)
#
# <b>Data validity:</b>
# - customer_address_postal: had to check for valid postal codes. Did a clean up to extract 6 digit postal codes. Those invalid was replaced with nulls.
#     - postal_good is the new feature to hold the valid postal codes
# - promotion_codes: has to do corrections on the strings, this allowed for the correct groupings of the promo codes
#     - promo_good is the new feature to hold the corrected promo codes
# - lead_time: was in minutes. Was reformated to 'DAYS:HRS:MINS' format, allowed for binning of the lead times
#     - lead_time_good is the new feature to hold the reformatted lead times
# - basket_size: **has 199 entries of 99999.0** >> These entries are would be deemed problematic, however we can revisit this to either impute or drop.
#     - If to be imputed: We would use the median to impute because the mean may be skewed by the rare-occasion large basket. Taking the median is a safer approach.
#     - For now, we will keep it and **EXCLUDE IT* for the Analysis (see tableau viz)
# - menu_id and merchant_type: No issues here as they were checked to match up. (no clashing or errors)
# - organisation_name_provided: nulls were imputed to 0

# %% [markdown]
# # Please see Tableau Dashboard for Orders for Dashboard Viz

# %% [markdown]
# https://public.tableau.com/profile/ziig.yee#!/vizhome/Oddle_Orders_Overview/SalesPerformanceDash
#
# - Please view in fullscreen >> Click the bottom left of the viz
# <img src=fullscreen.png>
